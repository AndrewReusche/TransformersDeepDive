# %% [markdown]
# Source: https://nlp.seas.harvard.edu/annotated-transformer/

# %% [markdown]
# # The Annotated Transformer
# The Transformer has been on a lot of people’s minds over the last year five years. This post presents an annotated version of the paper in the form of a line-by-line implementation. It reorders and deletes some sections from the original paper and adds comments throughout. This document itself is a working notebook, and should be a completely usable implementation. Code is available here.
#
# ## Prelims

# %%
# !pip install altair
# Out:
# Collecting altair
#   Downloading altair-6.0.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/torch/lib/python3.12/site-packages (from altair) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /opt/anaconda3/envs/torch/lib/python3.12/site-packages (from altair) (4.25.1)
# Collecting narwhals>=1.27.1 (from altair)
#   Downloading narwhals-2.14.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/torch/lib/python3.12/site-packages (from altair) (25.0)
# Requirement already satisfied: typing-extensions>=4.12.0 in /opt/anaconda3/envs/torch/lib/python3.12/site-packages (from altair) (4.15.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/torch/lib/python3.12/site-packages (from jsonschema>=3.0->altair) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/torch/lib/python3.12/site-packages (from jsonschema>=3.0->altair) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/torch/lib/python3.12/site-packages (from jsonschema>=3.0->altair) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/envs/torch/lib/python3.12/site-packages (from jsonschema>=3.0->altair) (0.27.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/torch/lib/python3.12/site-packages (from jinja2->altair) (3.0.2)
# Downloading altair-6.0.0-py3-none-any.whl (795 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 795.4/795.4 kB 11.5 MB/s  0:00:00
# Downloading narwhals-2.14.0-py3-none-any.whl (430 kB)
# Installing collected packages: narwhals, altair
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [altair]2m1/2 [altair]
# Successfully installed altair-6.0.0 narwhals-2.14.0

# %%
# !pip install --upgrade torchtext
# Out:
# Requirement already satisfied: torchtext in /opt/anaconda3/envs/torch/lib/python3.12/site-packages (0.18.0)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/torch/lib/python3.12/site-packages (from torchtext) (4.67.1)
# Requirement already satisfied: requests in /opt/anaconda3/envs/torch/lib/python3.12/site-packages (from torchtext) (2.32.5)
# Requirement already satisfied: torch>=2.3.0 in /opt/anaconda3/envs/torch/lib/python3.12/site-packages (from torchtext) (2.8.0)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/torch/lib/python3.12/site-packages (from torchtext) (2.3.3)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/torch/lib/python3.12/site-packages (from torch>=2.3.0->torchtext) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/anaconda3/envs/torch/lib/python3.12/site-packages (from torch>=2.3.0->torchtext) (4.15.0)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/torch/lib/python3.12/site-packages (from torch>=2.3.0->torchtext) (78.1.1)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/envs/torch/lib/python3.12/site-packages (from torch>=2.3.0->torchtext) (1.14.0)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/torch/lib/python3.12/site-packages (from torch>=2.3.0->torchtext) (3.5)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/torch/lib/python3.12/site-packages (from torch>=2.3.0->torchtext) (3.1.6)
# Requirement already satisfied: fsspec in /opt/anaconda3/envs/torch/lib/python3.12/site-packages (from torch>=2.3.0->torchtext) (2025.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/torch/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=2.3.0->torchtext) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/torch/lib/python3.12/site-packages (from jinja2->torch>=2.3.0->torchtext) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/torch/lib/python3.12/site-packages (from requests->torchtext) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/torch/lib/python3.12/site-packages (from requests->torchtext) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/torch/lib/python3.12/site-packages (from requests->torchtext) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/torch/lib/python3.12/site-packages (from requests->torchtext) (2025.8.3)

# %%
import os
from os.path import exists
import torch
import torch.nn as nn
from torch.nn.functional import log_softmax, pad
import math
import copy
import time
from torch.optim.lr_scheduler import LambdaLR
import pandas as pd
import altair as alt
from torchtext.data.functional import to_map_style_dataset
from torch.utils.data import DataLoader
from torchtext.vocab import build_vocab_from_iterator
import torchtext.datasets as datasets
import spacy
import GPUtil
import warnings
from torch.utils.data.distributed import DistributedSampler
import torch.distributed as dist
import torch.multiprocessing as mp
from torch.nn.parallel import DistributedDataParallel as DDP


# Set to False to skip notebook execution (e.g. for debugging)
warnings.filterwarnings("ignore")
RUN_EXAMPLES = True
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 12
#      10 import pandas as pd
#      11 import altair as alt
# ---> 12 from torchtext.data.functional import to_map_style_dataset
#      13 from torch.utils.data import DataLoader
#      14 from torchtext.vocab import build_vocab_from_iterator
#
# File /opt/anaconda3/envs/torch/lib/python3.12/site-packages/torchtext/__init__.py:18
#      15     _WARN = False
#      17 # the following import has to happen first in order to load the torchtext C++ library
# ---> 18 from torchtext import _extension  # noqa: F401
#      20 _TEXT_BUCKET = "https://download.pytorch.org/models/text/"
#      22 _CACHE_DIR = os.path.expanduser(os.path.join(_get_torch_home(), "text"))
#
# File /opt/anaconda3/envs/torch/lib/python3.12/site-packages/torchtext/_extension.py:64
#      59     # This import is for initializing the methods registered via PyBind11
#      60     # This has to happen after the base library is loaded
#      61     from torchtext import _torchtext  # noqa
# ---> 64 _init_extension()
#
# File /opt/anaconda3/envs/torch/lib/python3.12/site-packages/torchtext/_extension.py:58, in _init_extension()
#      55 if not _mod_utils.is_module_available("torchtext._torchtext"):
#      56     raise ImportError("torchtext C++ Extension is not found.")
# ---> 58 _load_lib("libtorchtext")
#      59 # This import is for initializing the methods registered via PyBind11
#      60 # This has to happen after the base library is loaded
#      61 from torchtext import _torchtext
#
# File /opt/anaconda3/envs/torch/lib/python3.12/site-packages/torchtext/_extension.py:50, in _load_lib(lib)
#      48 if not path.exists():
#      49     return False
# ---> 50 torch.ops.load_library(path)
#      51 return True
#
# File /opt/anaconda3/envs/torch/lib/python3.12/site-packages/torch/_ops.py:1478, in _Ops.load_library(self, path)
#    1473 path = _utils_internal.resolve_library_path(path)
#    1474 with dl_open_guard():
#    1475     # Import the shared library into the process, thus running its
#    1476     # static (global) initialization code in order to register custom
#    1477     # operators with the JIT.
# -> 1478     ctypes.CDLL(path)
#    1479 self.loaded_libraries.add(path)
#
# File /opt/anaconda3/envs/torch/lib/python3.12/ctypes/__init__.py:379, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     376 self._FuncPtr = _FuncPtr
#     378 if handle is None:
# --> 379     self._handle = _dlopen(self._name, mode)
#     380 else:
#     381     self._handle = handle
#
# OSError: dlopen(/opt/anaconda3/envs/torch/lib/python3.12/site-packages/torchtext/lib/libtorchtext.so, 0x0006): Symbol not found: __ZN3c105ErrorC1ENSt3__112basic_stringIcNS1_11char_traitsIcEENS1_9allocatorIcEEEES7_PKv
#   Referenced from: <7E3C8144-0701-3505-8587-6E953627B6AF> /opt/anaconda3/envs/torch/lib/python3.12/site-packages/torchtext/lib/libtorchtext.so
#   Expected in:     <D1057909-9D16-345A-8B8C-73FA6C3DB62C> /opt/anaconda3/envs/torch/lib/python3.12/site-packages/torch/lib/libc10.dylib
